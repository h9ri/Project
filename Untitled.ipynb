# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img = cv2.imread('orl_faces/s4/1.pgm',0)

# %%
np.shape(img)
# Out:
# (112, 92)

# %%
plt.imshow(img)
plt.show()

# %%
from scipy import fftpack

# %%
def get_2D_dct(img):
    """ Get 2D Cosine Transform of Image
    """
    return fftpack.dct(fftpack.dct(img.T, norm='ortho').T, norm='ortho')

def get_2d_idct(coefficients):
    """ Get 2D Inverse Cosine Transform of Image
    """
    return fftpack.idct(fftpack.idct(coefficients.T, norm='ortho').T, norm='ortho')

# %%
img=cv2.resize(img,(256,256))

# %%
dct = get_2D_dct(img)

# %%
plt.matshow(np.abs(dct[:50, :50]), cmap=plt.cm.Paired);

# %%
def get_reconstructed_image(raw):
    img = raw.clip(0, 255)
    img = img.astype('uint8')
    #img = Image.fromarray(img)
    return img

# %%
dct_size = img.shape[0]

# %%
reconstructed_images = []

for ii in range(dct_size):
    dct_copy = dct.copy()
    dct_copy[ii:,:] = 0
    dct_copy[:,ii:] = 0
    
    # Reconstructed image
    r_img = get_2d_idct(dct_copy);
    reconstructed_image = get_reconstructed_image(r_img);

    # Create a list of images
    reconstructed_images.append(reconstructed_image);

# %%
fig = plt.figure(figsize=(16, 16))
for ii in range(64):
    plt.subplot(8, 8, ii + 1)
    plt.imshow(reconstructed_images[ii], cmap=plt.cm.gray)
    plt.grid(False);
    plt.xticks([]);
    plt.yticks([]);

# %%
np.shape(dct)
# Out:
# (256, 256)

# %%
dct_copy=dct.copy()

# %%
dct_copy[16:,:] = 0
dct_copy[:,16:] = 0

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
from scipy import fftpack
im=[]
for i in range(40):
    for j in range(5):
        img = cv2.imread('orl_faces/s'+str(i+1)+'/'+str(j+1)+'.pgm',0)
        dct = get_2D_dct(img)
        im.append(dct)
mean=[]
for i in range(4,200,5):
    a=np.zeros((112,92))
    for j in range(i-4,i+1):
        a=a+im[j]        
    mean.append(a/10)
mean_within_class=np.asarray(mean)
a=np.zeros((112,92))
for i in range(40):
    a=a+mean_within_class[i]
total_mean_between_class=a/40
v=[]
for i in range(200):
    v.append(np.square(im[i]-mean_within_class[int(i/5)])) 
variance=[]
for i in range(4,200,5):
    a=np.zeros((112,92))
    for j in range(i-4,i+1):
        a=a+v[j]        
    variance.append(a/10)
a=np.zeros((112,92))
for i in range(40):
    a=a+variance[i]
total_variance_within=a/40
w=[]
for i in range(200):
    w.append(np.square(im[i]-total_mean_between_class))    
a=np.zeros((112,92))
for i in range(200):
    a=a+w[i]
total_variance_between=a/200
df=np.divide(total_variance,total_variance_between)

# %%
dct_inew=get_2d_idct(dct_copy);

# %%
img=get_reconstructed_image(dct_inew)
# Out:
# (256, 256)
# (256, 256)

# %%
plt.imshow(img, cmap=plt.cm.gray)

# %%
    dct_copy = dct.copy()
    dct_copy[50:,:] = 0
    dct_copy[:,50:] = 0
    
    # Reconstructed image
    r_img = get_2d_idct(dct_copy);
    reconstructed_image = get_reconstructed_image(r_img);

    # Create a list of images
    #reconstructed_images.append(reconstructed_image);

# %%
plt.imshow(reconstructed_image, cmap=plt.cm.gray)

# %%
i=2
img = cv2.imread('orl_faces/s1/'+str(i)+'.pgm',0)

# %%
np.shape(img)
# Out:
# (112, 92)

# %%
np.shape(dct_copy)
# Out:
# (112, 92)

# %%
dct_copy[50:,:] = 0
dct_copy[:,50:] = 0

# %%
d1=dct_copy[:25,:25]

# %%
d1=d1.ravel()

# %%
np.shape(d1)
# Out:
# (625,)

# %%
k
# Out:
# 40

# %%
im=[]
for i in range(40):
    for j in range(5):
        img = cv2.imread('orl_faces/s'+str(i+1)+'/'+str(j+1)+'.pgm',0)
        dct = get_2D_dct(img)
        #print(np.shape(img))
        im.append(dct)

# %%
np.shape(im)
# Out:
# (200, 112, 92)

# %%
mean=[]
for i in range(9,400,10):
    a=np.zeros((112,92))
    for j in range(i-9,i+1):
        a=a+im[j]        
    mean.append(a/10)
mean=np.asarray(mean)

# %%
mean=[]
for i in range(4,200,5):
    a=np.zeros((112,92))
    for j in range(i-4,i+1):
        a=a+im[j]        
    mean.append(a/10)
mean_within_class=np.asarray(mean)

# %%
np.shape(mean_within_class)
# Out:
# (40, 112, 92)

# %%
a=np.zeros((112,92))
for i in range(40):
    a=a+mean_within_class[i]
total_mean_between_class=a/40

# %%
v=[]
for i in range(200):
    v.append(np.square(im[i]-mean_within_class[int(i/5)]))

# %%
variance=[]
for i in range(4,200,5):
    a=np.zeros((112,92))
    for j in range(i-4,i+1):
        a=a+v[j]        
    variance.append(a/10)

# %%
np.shape(variance)
# Out:
# (40, 112, 92)

# %%
variance_within_class=np.asarray(variance)

# %%
a=np.zeros((112,92))
for i in range(40):
    a=a+variance[i]
total_variance_within=a/40

# %%
np.shape(total_variance_within)
# Out:
# (112, 92)

# %%
w=[]
for i in range(200):
    w.append(np.square(im[i]-total_mean_between_class))

# %%
a=np.zeros((112,92))
for i in range(200):
    a=a+w[i]
total_variance_between=a/200

# %%
np.shape(total_variance_between)
# Out:
# (112, 92)

# %%
df=np.divide(total_variance_between,total_variance_within,)

# %%
np.shape(df)
# Out:
# (112, 92)

# %%
row=np.max(df,axis=1)
column=np.max(df,axis=0)

# %%
com=np.concatenate((row,column),axis=0)

# %%
np.shape(com)
# Out:
# (204,)

# %%
com=np.sort(com)

# %%
com=list(set(com))

# %%
np.shape(com)
# Out:
# (182,)

# %%
com=np.sort(com)[::-1]

# %%
com=com[:150]

# %%
index=[]
for i in com:
    for j in range(112):
        for k in range(92):
            z=[]
            if i==df[j][k]:
                z=[j,k]
                #print(z)
                index.append(z)

# %%
np.shape(index)
# Out:
# (150, 2)

# %%
np.shape(im)
# Out:
# (200, 112, 92)

# %%
feature_vector=[]

# %%
for i in im:
    p=[]
    for j in index:
        p.append(i[j[0],j[1]])
    feature_vector.append(p)

# %%
np.shape(feature_vector)
# Out:
# (200, 150)

# %%
feature_vector=np.asarray(feature_vector)

# %%
image=cv2.imread('orl_faces/s1/10.pgm',0)

# %%
image_dct=get_2D_dct(image)

# %%
image_feature=[]
for j in index:
    image_feature.append(image_dct[j[0],j[1]])

# %%
distances=[]
for i in feature_vector:
    distances.append(np.linalg.norm(i-image_feature))

# %%
np.shape(distances)
# Out:
# (200,)

# %%
abc=np.argsort(distances)[:8]

# %%
abc
# Out:
# array([ 80,  84,  91,  90, 130, 158,  55,   1])

# %%
im2=im.copy()

# %%
np.shape(im2)
# Out:
# (200, 112, 92)

# %%
for i in im2:
    i[12:,:] = 0
    i[:,12:] = 0

# %%
image_dct[12:,:]=0
image_dct[:,12:]=0

# %%
im=[]
for i in range(40):
    for j in range(5):
        img = cv2.imread('orl_faces/s'+str(i+1)+'/'+str(j+6)+'.pgm',0)
        dct = get_2D_dct(img)
        #print(np.shape(img))
        im.append(dct)

# %%
np.shape(im)
# Out:
# (200, 112, 92)

# %%
image_feature=[]
a=[]
for i in im:
    a=[]
    for j in index:
        a.append(i[j[0],j[1]])
    image_feature.append(a)

# %%
np.shape(image_feature)
# Out:
# (200, 150)

# %%
a=[1,1,2,2,2,2,3,1]

# %%
b=np.bincount(a)

# %%
np.argmax(b)
# Out:
# 2

# %%
final_label=[]
for j in image_feature:
    distances=[]
    label=[]
    for i in feature_vector:
        distances.append(np.linalg.norm(i-j))
    abc=np.argsort(distances)[:5]
    for k in abc:
        label.append((k/5)+1)
    label=np.bincount(label)
    final_label.append(np.argmax(label))

# %%
np.shape(final_label)
# Out:
# (200,)

# %%
test_label=[]
for i in range(200):
    test_label.append(int(i/5)+1)

# %%
np.shape(test_label)
# Out:
# (200,)

# %%
count=0

# %%
for i in range(100):
    if final_label[i]==test_label[i]:
        count=count+1

# %%
count/100
# Out:
# 0.74
